# %%
import torchaudio
from stable_codec import StableCodec

model = StableCodec(
    pretrained_model = 'stabilityai/stable-codec-speech-16k'
)
model.set_posthoc_bottleneck("2x15625_700bps")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import torchaudio
# ----> 2 from stable_codec import StableCodec
#       4 model = StableCodec(
#       5     pretrained_model = 'stabilityai/stable-codec-speech-16k'
#       6 )
#       7 model.set_posthoc_bottleneck("2x15625_700bps")
#
# ModuleNotFoundError: No module named 'stable_codec'

# %%
audio_path = "music.wav"
waveform_orig, original_sampling_rate = torchaudio.load(audio_path)

# %%
latents, tokens = model.encode(audiopath)
decoded_audio = model.decode(tokens)
