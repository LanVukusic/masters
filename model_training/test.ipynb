# %%
import torch

# %%
out = torch.Tensor()
bubu = torch.rand((1,200,8))
out, bubu
# Out:
# (tensor([]),
#  tensor([[[0.5627, 0.3061, 0.4173,  ..., 0.2685, 0.5379, 0.1300],
#           [0.4139, 0.4301, 0.3750,  ..., 0.1358, 0.8145, 0.8498],
#           [0.2449, 0.4810, 0.6325,  ..., 0.6270, 0.0952, 0.7088],
#           ...,
#           [0.5082, 0.1496, 0.8100,  ..., 0.9038, 0.7072, 0.0519],
#           [0.2502, 0.3925, 0.5040,  ..., 0.7652, 0.1842, 0.5997],
#           [0.4643, 0.9368, 0.5161,  ..., 0.6098, 0.1463, 0.0283]]]))

# %%
a = torch.cat([out,bubu], dim=1)

# %%
a.shape
# Out:
# torch.Size([1, 200, 8])
